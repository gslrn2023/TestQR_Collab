# %% [markdown]
# <a href="https://colab.research.google.com/github/gslrn2023/TestQR_Collab/blob/main/qr_code_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Download/Clone the GitHub project inside Google Colab
# !git clone https://github.com/lincolnloop/python-qrcode.git

# 2. Change directory into the downloaded project folder
# %cd python-qrcode

# 3. Install the project dependencies locally in Colab
# !pip install -e .[pil]

# 4. Import the library from the cloned GitHub project and generate output
import qrcode

# Create a customized QR code
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=10,
    border=4,
)
qr.add_data("https://github.com/gslrn2023")
qr.make(fit=True)

# Generate and display the image directly inside Colab
img = qr.make_image(fill_color="#1e3a8a", back_color="#f0f9ff")
img
# Out:
# Cloning into 'python-qrcode'...
# remote: Enumerating objects: 2761, done.
# remote: Counting objects: 100% (824/824), done.
# remote: Compressing objects: 100% (260/260), done.
# remote: Total 2761 (delta 705), reused 575 (delta 564), pack-reused 1937 (from 2)
# Receiving objects: 100% (2761/2761), 1.03 MiB | 7.73 MiB/s, done.
# Resolving deltas: 100% (1812/1812), done.
# /content/python-qrcode
# Obtaining file:///content/python-qrcode
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: deprecation in /usr/local/lib/python3.13/dist-packages (from qrcode==8.2) (2.1.0)
# Requirement already satisfied: pillow>=9.1.0 in /usr/local/lib/python3.13/dist-packages (from qrcode==8.2) (11.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from deprecation->qrcode==8.2) (26.3)
# Building wheels for collected packages: qrcode
#   Building editable for qrcode (pyproject.toml) ... done
#   Created wheel for qrcode: filename=qrcode-8.2-py3-none-any.whl size=10314 sha256=aa549dd5f4aa754aea68c73b9a74df69f39697df57cea9c78843b2817ebaadbd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n2tv812k/wheels/de/47/86/41b22fd320e51d267509b6f58437c753b482a102830a85023b
# Successfully built qrcode
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
